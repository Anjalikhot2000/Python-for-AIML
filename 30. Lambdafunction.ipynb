# %%
# Lambda function
# - Anonymous function
# Syntax
# lambda input:expression

# %%
x=lambda x:x**2
x(9)
# Out:
# 81

# %%
a=lambda x,y:x+y
a(2,3)
# Out:
# 5

# %%
b=lambda x:x[0]=="a"
b("apple")
# Out:
# True

# %%
b=lambda x:"Even" if x%2==0 else "Odd"
b(5)
# Out:
# 'Odd'

# %%
b(2)
# Out:
# 'Even'

# %%
# higher order function
l=[11,14,21,23,56,78,45,29,28]
def return_sum(func,l):
  res=0
  for i in l:
    if func(i):
      res+=i
  return res


x=lambda x:x%2==0
y=lambda x:x%2!=0
z=lambda x:x%3!=0

print(return_sum(x,l))
print(return_sum(y,l))
print(return_sum(z,l))
# Out:
# 176
# 129
# 161

# %%
# map
# map(function,iteratables)

l=[1,2,3,4,5]
a=list(map(lambda x:x*2,l))
a
# Out:
# [2, 4, 6, 8, 10]

# %%
a=list(map(lambda x:"Even" if x%2==0 else "Odd",l))

# %%
a
# Out:
# ['Odd', 'Even', 'Odd', 'Even', 'Odd']

# %%
stud=[{
    "name":"A",
    "Gender":"F"
},
      {"name":"B",
      "Gender":"M"}]
names=list(map(lambda x:x["name"],stud))

# %%
names
# Out:
# ['A', 'B']

# %%
# Filter

l=[1,2,3,4,5,67,8]
a=list(filter(lambda x:x>4,l))
a
# Out:
# [5, 67, 8]

# %%
fruits=["apple","orange","mango","guava"]
a=list(filter(lambda fruit:"e" in fruit,fruits))
a
# Out:
# ['apple', 'orange']

# %%
# reduce
import functools
l=[1,2,3,4,5,67,8]
a=functools.reduce(lambda x,y:x+y,l)
a
# Out:
# 90

# %%
functools.reduce(lambda x,y: x if x>y else y,l)
# Out:
# 67

# %%
# List comprehension
l=[1,2,3,4,5,6]
l1=[item*2 for item in l]
l1
# Out:
# [2, 4, 6, 8, 10, 12]

# %%
l2=[i for i in range(10) if i%2!=0]
l2
# Out:
# [1, 3, 5, 7, 9]

# %%
fruits
# Out:
# ['apple', 'orange', 'mango', 'guava']

# %%
o=[i for i in fruits if "o" in i]
o
# Out:
# ['orange', 'mango']

# %%
d={"Name":"Anjali","Gender":"Female","Age":25}

# %%
d.items()
# Out:
# dict_items([('Name', 'Anjali'), ('Gender', 'Female'), ('Age', 25)])

# %%
d1={key:value for key,value in d.items() if len(key)>3}

# %%
d1
# Out:
# {'Name': 'Anjali', 'Gender': 'Female'}

# %%
l=[1,2,3,4]
d2={item:item*2 for item in l}
d2
# Out:
# {1: 2, 2: 4, 3: 6, 4: 8}
