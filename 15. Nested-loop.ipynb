# %%
# Nested loop
# *
# **
# ***
# ****
# *****

# %%
num=int(input("enter a number:"))
for i in range(1,num+1):
  for j in range(0,i):
    print("*",end="")
  print()
# Out:
# enter a number:5
# *
# **
# ***
# ****
# *****
