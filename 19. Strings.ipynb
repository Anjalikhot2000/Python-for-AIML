# %%
# Strings
# Strings are sequence of unicode characters
# We can:
# - Create
# - Access
# - Adding chars to strings
# - Edit
# - Delete
# - Operations
# - String functions

# %%
# Creating
c="Hello"
print(c)
# Out:
# Hello

# %%
c="Hello !!! 'Anjali'"

# %%
print(c)
# Out:
# Hello !!! 'Anjali'

# %%
c="It's raning"
print(c)
# Out:
# It's raning

# %%
c=str('hello')
c
# Out:
# 'hello'
