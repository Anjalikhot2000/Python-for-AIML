# %%
# concept of indexing
c="Hello"
print(c)
print(c[0])
# Out:
# Hello
# H

# %%
# Types of index
# - positive Index
# - Negative
#Positive
print(c[4])
# Negative
print(c[-1])
# Out:
# o
# o

# %%
# Slicing
print(c[0:])
# Out:
# Hello

# %%
print(c[-1::-1])
# Out:
# olleH

# %%
print(c[0:8:2])
# Out:
# Hlo

# %%
print(c[0:6:-1])
