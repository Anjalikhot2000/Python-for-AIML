# %%
# List
# - List is a data structure in python which is a collection of hetergenous data.Its mutable
# Array
# - Array is homogenous. Array need continous memory. It is faster to access compare to list. Array is less programmer friendly  commpare to list

# %%
# Creation of list
# Empty list
l1=[]
print(a)
# Out:
# []

# %%
# homogenous list
a=[1,2,3,4]
print(a)
# Out:
# [1, 2, 3, 4]

# %%
# heterogenous list
a=[1,"a",2.5]
print(a)
# Out:
# [1, 'a', 2.5]

# %%
# Multi-dimensional list
# 2D
a=[[1,2],[3,4]]
print(a)
# Out:
# [[1, 2], [3, 4]]

# %%
# Accessing of element from list
a=[1,2,3]
print(a[0])
print(a[:])
print(a[::-1])
for i  in a:
  print(i)
# Out:
# 1
# [1, 2, 3]
# [3, 2, 1]
# 1
# 2
# 3

# %%
l2=[[1,2],[3,4]]
print(l2[1][0])
# Out:
# 3

# %%
l1=[[[1,2],[2,3]],[5]]
print(l1[0][1][0])
# Out:
# 2

# %%
# Editing of list
l1=[1,2,3]
l1[0]=5
l1
# Out:
# [5, 2, 3]

# %%
# Add
# append
# extend
# insert

l1.append(100)
l1
# Out:
# [5, 2, 3, 100]

# %%
l1.extend([500,600,700])
l1
# Out:
# [5, 2, 3, 100, 500, 600, 700]

# %%
l1.insert(3,"Hey")

# %%
l1
# Out:
# [5, 2, 3, 'Hey', 100, 500, 600, 700]

# %%
from os import remove
# delete
# del
# remove
# pop
# clear

l2=[1,2,3,4]
l2
# Out:
# [1, 2, 3, 4]

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1735/2371406284.py in <cell line: 0>()
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2=[1,2,3,4]
l2
# Out:
# [1, 2, 3, 4]

# %%
del l2[0]

# %%
l2
# Out:
# [2, 3, 4]

# %%
l2.remove(3)

# %%
l2
# Out:
# [2, 4]

# %%
l2.pop()
# Out:
# 4

# %%
l2
# Out:
# [2]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
# Operations
l1=[1,2,3]
l2=[4,5,6]
l1+l2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l1*3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
for i in l2:
  print(i)
# Out:
# 4
# 5
# 6

# %%
4 in l2
# Out:
# True

# %%
# Functions
len(l2)
# Out:
# 3

# %%
min(l2)
# Out:
# 4

# %%
max(l2)
# Out:
# 6

# %%
sorted(l2,reverse=True) # new list
# Out:
# [6, 5, 4]

# %%
l2.sort(reverse=True) # permanent

# %%
l2
# Out:
# [6, 5, 4]

# %%
l2.index(4)
# Out:
# 2

# %%
s="hello how are you"
l=s.split(" ")
l1=[]
for i in range(len(l)):
  l1.append(l[i][0].upper()+l[i][1:])
s=" ".join(l1)
s
# Out:
# 'Hello How Are You'

# %%
a="abc@gmail.com"
a[:a.find("@")]
# Out:
# 'abc'

# %%
l1=[1,1,2,3,4,2,2,3]
l2=[]
for i in l1:
  if i not in l2:
    l2.append(i)
print(l2)
# Out:
# [1, 2, 3, 4]
