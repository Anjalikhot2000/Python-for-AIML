# %% [markdown]
# Variables
# - variables are used to store data that can be referenced and manipulated during program execution.
# - Dynamic typing: No need to declare the type of data type. No need to declare variable
# - Dynamic binding: A variable which can change data type.

# %%
name ="Anjali"

# %%
print(name)

# %%
a=5;b=3;c=1
print(a,b,c)
# Out:
# 5 3 1

# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3
