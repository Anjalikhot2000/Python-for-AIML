# %% [markdown]
# Operators
# - Operators are used to perform operations on variables and values. Python has following operators:
#   - Arithmetic
#   - Comparision
#   - Logical
#   - Bitwise
#   - Assignment
#   - Identity
#   - Membership

# %%
# Arithmetic
x=2
y=5
print(x+y)
# Out:
# 7

# %%
print(x-y)
# Out:
# -3

# %%
print(x*y)
# Out:
# 10

# %%
print(x/y)
# Out:
# 0.4

# %%
print(x%y)
# Out:
# 2

# %%
print(x**y)
# Out:
# 32

# %%
print(x//y)
# Out:
# 0

# %%
# Comparision
print(x>y)
# Out:
# False

# %%
print(x<y)
# Out:
# True

# %%
print(x>=y)
# Out:
# False

# %%
print(x<=y)
# Out:
# True

# %%
print(x==y)
# Out:
# False

# %%
print(x!=y)
# Out:
# True

# %%
# Logical
x=True
y=False

print(x or y)
# Out:
# True

# %%
print (x and y)
# Out:
# False

# %%
print(not x)
# Out:
# False

# %%
# Bitwise

x=2
y=3
print(x & y)
# Out:
# 2

# %%
print(x |y)
# Out:
# 3

# %%
print(x>>y)
# Out:
# 0

# %%
print(y<<3)
# Out:
# 24

# %%
print(~x)
# Out:
# -3

# %%
# Assignment
a=3
print(a)
# Out:
# 3

# %%
a+=3
print(a)
# Out:
# 12

# %%
a-=3
print(a)
# Out:
# 9

# %%
a*=2
print(a)
# Out:
# 18

# %%
a&=3
print(a)
# Out:
# 2

# %%
# Identity
a=3
b=3
print(a is b)
# Out:
# True

# %%
a="hello"
b="hello"
print( a is b)
# Out:
# True

# %%
a=[1,2,3]
b=[1,2,3]
print(a is b)
# Out:
# False

# %%
# Membership
x="Delhi"
print( "D" in x)
print( "D" not in x)
# Out:
# True
# False

# %%
l=[1,2,3,4,5]
if 6 in l:
    print("present")
else:
    print("not present")
# Out:
# not present
