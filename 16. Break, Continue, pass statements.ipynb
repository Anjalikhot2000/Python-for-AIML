# %%
# break
# - if we want to terminate the loop
for i in range(1,11):
  if i==5:
    break
  print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# continue
for i in range(1,11):
  if i==5:
    continue
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 6
# 7
# 8
# 9
# 10

# %%
# pass
for i in range(1,11):
  pass
