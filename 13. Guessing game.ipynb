# %%
import random

num=random.randint(1,6)
num1=int(input("Enter a number"))
count=1
while num!=num1:
  if num1>num:
    num1=int(input("Guess lower"))
  else:
    num1=int(input("Guess higher"))
    count+=1
print("The guessed number is",num1,"is correct and the taken attempt(s)",count)
# Out:
# Enter a number2
# Guess higher1
# Guess higher4
# Guess higher5
# The guessed number is 5 is correct and the taken attempt(s) 4
