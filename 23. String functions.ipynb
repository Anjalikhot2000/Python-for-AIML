# %%
# Common functions
# - Len
# - max
# - min
# - sorted

# %%
c="Bangalore"
len(c)
# Out:
# 9

# %%
max(c)
# Out:
# 'r'

# %%
min(c)
# Out:
# 'B'

# %%
sorted(c, reverse=True)
# Out:
# ['r', 'o', 'n', 'l', 'g', 'e', 'a', 'a', 'B']

# %%
# Capitalize/Upper/Lower/SwapCase

# %%
c="Bangalore"

# %%
c.capitalize()
# Out:
# 'Bangalore'

# %%
c.title()
# Out:
# 'Bangalore'

# %%
c.upper()
# Out:
# 'BANGALORE'

# %%
c.lower()
# Out:
# 'bangalore'

# %%
c.swapcase()
# Out:
# 'bANGALORE'

# %%
# Count
"it is raining".count("i")
# Out:
# 4

# %%
# Find/Index

# %%
"it is raining".find("i")
# Out:
# 0

# %%
"it is raining".find("f")
# Out:
# -1

# %%
"it is raining".index("i")
# Out:
# 0

# %%
"it is raining".index("f")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_451/2477778533.py in <cell line: 0>()
# ----> 1 "it is raining".index("f")
#
# ValueError: substring not found

# %%
# endswith/startswith

# %%
"it is raining".endswith("ij")
# Out:
# False

# %%
"it is raining".startswith("it")
# Out:
# True

# %%
# format

# %%
a="Hello my name is {} and i m in {}".format("Anjali","Goa")

# %%
a
# Out:
# 'Hello my name is Anjali and i m in Goa'

# %%
a="Hello my name is {1} and i m in {0}".format("Anjali","Goa")

# %%
a
# Out:
# 'Hello my name is Goa and i m in Anjali'

# %%
a="Hello my name is {name} and i m in {place}".format(name="Anjali",place="Goa")

# %%
a
# Out:
# 'Hello my name is Anjali and i m in Goa'

# %%
# isalnum/isalpha/isdigit/isidentifier

# %%
"Flat20".isalnum()
# Out:
# True

# %%
"Flat20".isalpha()
# Out:
# False

# %%
"Flat20".isdigit()
# Out:
# False

# %%
"hello_world".isidentifier()
# Out:
# True

# %%
# split
a="Banana,Apple,Mango"
b=a.split(",")
b
# Out:
# ['Banana', 'Apple', 'Mango']

# %%
# join
a=" ".join(b)
a
# Out:
# 'Banana Apple Mango'

# %%
# replace
c="Hello"
c.replace("H","e")
# Out:
# 'eello'

# %%
#strip
c="        Hello           "
c
# Out:
# '        Hello           '

# %%
c.strip()
# Out:
# 'Hello'
