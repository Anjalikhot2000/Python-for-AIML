# %% [markdown]
# **Loops**
#
# - Iteration controlling block

# %%
# While
num1=int(input("Enter the number you want to print its table:"))
i=1
while i<=10:
  print(num1,"*",i,"=",num1*i)
  i+=1
# Out:
# Enter the number you want to print its table:2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
