# %%
# # Sets
# - Sets do not allow duplicate
# - Sets are unordered(no-indexing)
# - Sets dont allow mutable data type
# - Sets itself is mutable data type

# %%
# Creation
a=set()
a
# Out:
# set()

# %%
s1={1,2,3,4,5}
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2={1,2,"a",3}
s2
# Out:
# {1, 2, 3, 'a'}

# %%
s3={1,2,3,4,1} # no-duplicates
s3
# Out:
# {1, 2, 3, 4}

# %%
s4={[1,2],3} # Sets dont allow mutable data type
s4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/3796685686.py in <cell line: 0>()
# ----> 1 s4={[1,2],3} # Sets dont allow mutable data type
#       2 s4
#
# TypeError: unhashable type: 'list'

# %%
s4={(1,2),"Hello"}
s4
# Out:
# {(1, 2), 'Hello'}

# %%
s5={{1},{2,3}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/3744305875.py in <cell line: 0>()
# ----> 1 s5={{1},{2,3}}
#
# TypeError: unhashable type: 'set'

# %%
# Access
s1={1,2,3}
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/3302942708.py in <cell line: 0>()
#       1 # Access
#       2 s1={1,2,3}
# ----> 3 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
# Edit
s1[0]=5
s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/323193194.py in <cell line: 0>()
#       1 # Edit
# ----> 2 s1[0]=5
#       3 s1
#
# TypeError: 'set' object does not support item assignment

# %%
# add
s1.add(4)
s1
# Out:
# {1, 2, 3, 4}

# %%
# Delete
# del
# remove
# pop

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/1234754133.py in <cell line: 0>()
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
s1={1,2,3}
s1.remove(1)

# %%
s1
# Out:
# {2, 3}

# %%
s1.pop()
# Out:
# 2

# %%
s1
# Out:
# {3}

# %%
# Set Operations
s1={1,2,3,4,5}
s2={3,4,5,6,7}
s1+s1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/2606826330.py in <cell line: 0>()
#       2 s1={1,2,3,4,5}
#       3 s2={3,4,5,6,7}
# ----> 4 s1+s1
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
s1*2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_252/64980944.py in <cell line: 0>()
# ----> 1 s1*2
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
for i in s1:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# Functions

# %%
len(s1)
# Out:
# 5

# %%
min(s1)
# Out:
# 1

# %%
max(s1)
# Out:
# 5

# %%
sum(s1)
# Out:
# 15

# %%
sorted(s1)
# Out:
# [1, 2, 3, 4, 5]

# %%
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2
# Out:
# {3, 4, 5, 6, 7}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s1.intersection(s2)
# Out:
# {3, 4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 6, 7}

# %%
s1.isdisjoint(s2)
# Out:
# False

# %%
s1.issubset(s2)
# Out:
# False

# %%
s1.issuperset(s2)
# Out:
# False
