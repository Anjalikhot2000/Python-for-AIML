# %%
print("Anjali")
# Out:
# Anjali

# %%
print(5.6)
# Out:
# 5.6

# %%
print("India","USA")
# Out:
# India USA

# %%
print("India","USA",sep="*")
# Out:
# India*USA

# %%
print("India","USA",sep="/",end="**")
print("Anjali")
# Out:
# India/USA**Anjali
