# %% [markdown]
# Type-Conversion
#
# - Converting one data-type into another data-type
# - Types:
#   - Implicit: no need to tell
#   - Explicit: need to explicitly tell

# %%
# implicit
4+4.5+5j
# Out:
# (8.5+5j)

# %%
3+2.5
# Out:
# 5.5

# %%
# Explicit
int(4.5)
# Out:
# 4

# %%
float(4)
# Out:
# 4.0

# %%
a=list('Hello')
