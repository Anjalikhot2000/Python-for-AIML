# %%
# Tuples
# - Tuple is collection of heterogenous elememts
# - Tuples are immutable

# %%
#Create
a=()
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=(1,2,3,"a")
a
# Out:
# (1, 2, 3, 'a')

# %%
# Access
a[0]
# Out:
# 1

# %%
a[:9]
# Out:
# (1, 2, 3, 'a')

# %%
a[-1:]
# Out:
# ('a',)

# %%
a[:-1]
# Out:
# (1, 2, 3)

# %%
for i in a:
  print(i)
# Out:
# 1
# 2
# 3
# a

# %%
# Edit - Tuples are not editable
a[0]=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_364/1571828338.py in <cell line: 0>()
#       1 # Edit
# ----> 2 a[0]=1
#
# TypeError: 'tuple' object does not support item assignment

# %%
# Add - Elements cannot be added once created

# %%
#deleting
del a

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_364/2167009006.py in <cell line: 0>()
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
t=(1,2,3,4)
del  t[-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_364/2049722115.py in <cell line: 0>()
#       1 t=(1,2,3,4)
# ----> 2 del  t[-1]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
# Functions
t=(1,2,3,4)
len(t)
# Out:
# 4

# %%
min(t)
# Out:
# 1

# %%
max(t)
# Out:
# 4

# %%
sum(t)
# Out:
# 10

# %%
sorted(t)
# Out:
# [1, 2, 3, 4]

# %%
# Operations
t1=(1,2,3)
t2=(4,7,3)

# %%
t1+t2
# Out:
# (1, 2, 3, 4, 7, 3)

# %%
t1*3
# Out:
# (1, 2, 3, 1, 2, 3, 1, 2, 3)
