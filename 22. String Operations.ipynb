# %% [markdown]
# Operations on String
#
# - Arithmetic
# - Relational
# - Logical
# - Loops
# - Membership

# %%
# Arithmetic
"a"+"b" # Concat
# Out:
# 'ab'

# %%
"a"*3
# Out:
# 'aaa'

# %%
# Relational
"a"=="b"
# Out:
# False

# %%
"a"!="b"
# Out:
# True

# %%
#Lexiographically
"Goa"<"Kolkata"
# Out:
# True

# %%
"Mumbai">"Pune"
# Out:
# False

# %%
#Logical
"Hello" and "world"
# Out:
# 'world'

# %%
# ""=False
# "wdsefds"=True

# %%
#Loops
c="Hello"
for i in c:
  print (i)
# Out:
# H
# e
# l
# l
# o

# %%
# membership
if "H" in c:
  print("YO")
# Out:
# YO
