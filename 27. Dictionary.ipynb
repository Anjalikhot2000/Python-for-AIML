# %%
# Dictionary
# - The data is stored in key value pair
# - no-indexing
# - It is mutable type, key are immutable and values can be mutable as well as immutable
# - Keys should be unique

# %%
# Create
d={}
print(type(d))
# Out:
# <class 'dict'>

# %%
d1={"Name":"Anjali","Gender":"Female"}
d1
# Out:
# {'Name': 'Anjali', 'Gender': 'Female'}

# %%
d2={[1,2,3]:"Anjali"} # Keys are immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/1865294184.py in <cell line: 0>()
# ----> 1 d2={[1,2,3]:"Anjali"} # Keys are immutable
#
# TypeError: unhashable type: 'list'

# %%
d2={"Anjali":[1,22,3]}

# %%
d3={'Name':"Anjali","Name":"Virat"}
d3
# Out:
# {'Name': 'Virat'}

# %%
d4={"Name":"Anjali","College":"DYP","Marks":{"CS":99,"CN":80}}
d4
# Out:
# {'Name': 'Anjali', 'College': 'DYP', 'Marks': {'CS': 99, 'CN': 80}}

# %%
d4.get("Name")
# Out:
# 'Virat'

# %%
d4["Marks"]["CS"]
# Out:
# 99

# %%
# Acess
d4["Name"]
# Out:
# 'Anjali'

# %%
# Edit
d4["Name"]="Virat"
d4
# Out:
# {'Name': 'Virat', 'College': 'DYP', 'Marks': {'CS': 99, 'CN': 80}}

# %%
# Add new value
d4["Age"]=25
d4
# Out:
# {'Name': 'Virat', 'College': 'DYP', 'Marks': {'CS': 99, 'CN': 80}, 'Age': 25}

# %%
d5={}

# %%
# delete
d5
# Out:
# {}

# %%
del d5

# %%
d5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/641744681.py in <cell line: 0>()
# ----> 1 d5
#
# NameError: name 'd5' is not defined

# %%
d1
# Out:
# {'Name': 'Anjali', 'Gender': 'Female'}

# %%
del d1["Gender"]

# %%
d1
# Out:
# {'Name': 'Anjali'}

# %%
d1.clear()

# %%
# Operation
d1={"Name":"Anjali","Gender":"Female"}
d2={"Name":"Virat","Gender":"Male"}
d1+d2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/2897980433.py in <cell line: 0>()
#       2 d1={"Name":"Anjali","Gender":"Female"}
#       3 d2={"Name":"Virat","Gender":"Male"}
# ----> 4 d1+d2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
d1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3494/1279314104.py in <cell line: 0>()
# ----> 1 d1*3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %%
d4
# Out:
# {'Name': 'Virat', 'College': 'DYP', 'Marks': {'CS': 99, 'CN': 80}, 'Age': 25}

# %%
for i in d4:
  print(i) # Keys
# Out:
# Name
# College
# Marks
# Age

# %%
for i in d4:
  print(i,":",d4[i])
# Out:
# Name : Virat
# College : DYP
# Marks : {'CS': 99, 'CN': 80}
# Age : 25

# %%
for key,value in d4.items():
  print(key,":",value)
# Out:
# Name : Virat
# College : DYP
# Marks : {'CS': 99, 'CN': 80}
# Age : 25

# %%
"Virat" in d4 # checks only keys not values
# Out:
# False

# %%
"Name" in d4
# Out:
# True

# %%
len(d4)
# Out:
# 4

# %%
min(d4)
# Out:
# 'Age'

# %%
max(d4)
# Out:
# 'Name'

# %%
sorted(d4)
# Out:
# ['Age', 'College', 'Marks', 'Name']

# %%
d4.keys()
# Out:
# dict_keys(['Name', 'College', 'Marks', 'Age'])

# %%
d4.values()
# Out:
# dict_values(['Virat', 'DYP', {'CS': 99, 'CN': 80}, 25])

# %%
d4.items()
# Out:
# dict_items([('Name', 'Virat'), ('College', 'DYP'), ('Marks', {'CS': 99, 'CN': 80}), ('Age', 25)])

# %%
id='cor'
