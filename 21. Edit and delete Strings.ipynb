# %%
c="Hello"
print(c)
# Out:
# Hello

# %%
c[0]="X" # String doesnt allow editing - Strings are immutable data type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_169/4107867293.py in <cell line: 0>()
# ----> 1 c[0]="X"
#
# TypeError: 'str' object does not support item assignment

# %%
del c

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_169/3235490055.py in <cell line: 0>()
# ----> 1 c
#
# NameError: name 'c' is not defined

# %%
c="Hello"
del c[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_169/1848371096.py in <cell line: 0>()
#       1 c="Hello"
# ----> 2 del c[0]
#
# TypeError: 'str' object doesn't support item deletion
